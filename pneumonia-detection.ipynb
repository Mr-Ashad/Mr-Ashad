# %%
import os
import pandas as pd
from os import listdir, makedirs, getcwd, remove
from os.path import isfile, join, abspath, exists, isdir, expanduser
from PIL import Image
from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image
# !pip install efficientnet-pytorch
import torch 
from torchvision import datasets,transforms
from efficientnet_pytorch import EfficientNet
from torch.utils.data import DataLoader
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16427 sha256=f237264f7e08ac45fcd23bb5b85fd524f8664572dd42af6f9d8e14f1e2c6c83e
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet-pytorch

# %%
data_dir = Path('../input/chest-xray-pneumonia/chest_xray')

train_dir = data_dir / 'train'

val_dir = data_dir / 'val'

test_dir = data_dir / 'test'

# %%
normal_cases_dir = train_dir / 'NORMAL'
pneumonia_cases_dir = train_dir / 'PNEUMONIA'

normal_cases = normal_cases_dir.glob('*.jpeg')
pneumonia_cases = pneumonia_cses_dir.glob('*.jpeg')

# Add normal cases with label 0 and pneumonia cases with label 1
train_data = [(img, 0) for img in normal_cases] + [(img, 1) for img in pneumonia_cases]

train_data = pd.DataFrame(train_data,columns =['image','label'],index=None)

train_data = train_data.sample(frac=1.).reset_index(drop=True)

# %%
train_data

# %%
class_distribution = train_data['label'].value_counts()

# %%
class_distribution

# %%
class_distribution.plot(kind='bar',color=['blue','red'])
plt.title("Class Distribution")
plt.xlabel("Class")
plt.ylabel("No of Images")

plt.xticks(ticks=[0,1],labels=['Normal','Pneumonia'],rotation=0)
plt.show()

# %%
print(normal_cases_dir)
print(pneumonia_cases_dir)

# %%
normal_cases = list(normal_cases)
pneumonia_cases = list(pneumonia_cases)

print(normal_cases[:5])  # Check the first 5 normal images
print(pneumonia_cases[:5])  # Check the first 5 pneumonia images

# %%
print(normal_cases)

# %%
normal_images = list(normal_cases)[:5]
pneumonia_images = list(pneumonia_cases)[:5]

plt.figure(figsize=(15,5))

for i, img_path in enumerate(normal_images):
    img = Image.open(img_path)
    if img.mode != 'L':
        img = img.convert('L')
    plt.subplot(2,5,i + 1)
    plt.imshow(img)
    plt.title('Normal')
    plt.axis('off')    

for i, img_path in enumerate(pneumonia_images):
    img = Image.open(img_path)
    if img.mode != 'L':
        img = img.convert('L')
    plt.subplot(2,5,5 + i + 1)
    plt.imshow(img)
    plt.title('Pneumonia')
    plt.axis('off')    

plt.show()
